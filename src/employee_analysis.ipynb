# %%
import pandas as pd 

inventory = pd.read_csv("data/inventory.csv")
products = pd.read_csv("data/products.csv")
promotions = pd.read_csv("data/promotions.csv")
transactions = pd.read_csv("data/transactions.csv")
#Research question: What are the peak hours/days in terms of transactions and customers? employee and customer perspective

# %%
transactions["hour"] = pd.to_datetime(transactions['time'], format='%H:%M:%S').dt.hour
transactions["nday"] = pd.to_datetime(transactions["day"], dayfirst=True).dt.dayofyear

# %%
transactions_hourly = transactions.groupby(["nday","hour"]).count()["customer"]
#df_transact_hourly = pd.DataFrame({"hour":transactions_hourly.index, "nr. transactions":transactions_hourly.values})

# %%
def extract_hours(row):
    hour = row.index[2]
    return hour
transactions_hourly
# Out:
# nday   hour
# 1.0    9.0      39
#        10.0     73
#        11.0     75
#        12.0     34
#        13.0    173
#               ...
# 364.0  16.0     68
#        17.0    117
#        18.0     98
#        19.0     80
#        20.0     72
# Name: customer, Length: 4320, dtype: int64

# %%
days = [transactions_hourly.index[i][0] for i in range(len(transactions_hourly))]
hours = [transactions_hourly.index[i][1] for i in range(len(transactions_hourly))]

df_transactions = pd.DataFrame({"days":days, "hours":hours, "transactions":transactions_hourly.values})
df_transactions
# Out:
#        days  hours  transactions
# 0       1.0    9.0            39
# 1       1.0   10.0            73
# 2       1.0   11.0            75
# 3       1.0   12.0            34
# 4       1.0   13.0           173
# ...     ...    ...           ...
# 4315  364.0   16.0            68
# 4316  364.0   17.0           117
# 4317  364.0   18.0            98
# 4318  364.0   19.0            80
# 4319  364.0   20.0            72
#
# [4320 rows x 3 columns]

# %%
import plotly.express as px
fig = px.box(df_transactions, x="hours", y="transactions", color="hours")
fig.show()

# %%
import plotly.express as px
fig = px.line(df_transact_hourly, x = "hour", y="nr. transactions", title="Number of transactions per hour")
fig.update_yaxes(range=(20000,35000))
fig.show()
#CHANGE Y AXIS RANGE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-95cb0e699a43> in <module>
#       1 import plotly.express as px
# ----> 2 fig = px.line(df_transact_hourly, x = "hour", y="nr. transactions", title="Number of transactions per hour")
#       3 fig.update_yaxes(range=(20000,35000))
#       4 fig.show()
#       5 #CHANGE Y AXIS RANGE
#
# NameError: name 'df_transact_hourly' is not defined

# %%
transactions.dropna(subset=["day"], inplace=True)

# %%
transactions
# Out:
#                day      time  customer  bank acount   category product_id  \
# 0         1/1/2018   9:07:00       0.0          NaN      snack        s_5
# 1         1/1/2018   9:07:00       0.0          NaN       meat       m_16
# 2         1/1/2018   9:07:00       0.0          NaN       meat       m_18
# 3         1/1/2018   9:07:00       0.0          NaN       meat        m_6
# 4         1/1/2018   9:07:00       0.0          NaN      bread       b_33
# ...            ...       ...       ...          ...        ...        ...
# 354860  30-12-2018  20:59:33   20685.0          NaN       meat        m_1
# 354861  30-12-2018  20:59:33   20685.0          NaN      fruit       f_26
# 354862  30-12-2018  20:59:33   20685.0          NaN       meat       m_24
# 354863  30-12-2018  20:59:33   20685.0          NaN       meat       m_18
# 354864  30-12-2018  20:59:33   20685.0          NaN  vegetable       v_26
#
#                       description  size  std_sales_price  purchase_price  bio  \
# ...

# %%
from datetime import datetime
transactions["day"] = pd.to_datetime(transactions["day"])
transactions
# Out:
#               day      time  customer  bank acount   category product_id  \
# 0      2018-01-01   9:07:00       0.0          NaN      snack        s_5
# 1      2018-01-01   9:07:00       0.0          NaN       meat       m_16
# 2      2018-01-01   9:07:00       0.0          NaN       meat       m_18
# 3      2018-01-01   9:07:00       0.0          NaN       meat        m_6
# 4      2018-01-01   9:07:00       0.0          NaN      bread       b_33
# ...           ...       ...       ...          ...        ...        ...
# 354860 2018-12-30  20:59:33   20685.0          NaN       meat        m_1
# 354861 2018-12-30  20:59:33   20685.0          NaN      fruit       f_26
# 354862 2018-12-30  20:59:33   20685.0          NaN       meat       m_24
# 354863 2018-12-30  20:59:33   20685.0          NaN       meat       m_18
# 354864 2018-12-30  20:59:33   20685.0          NaN  vegetable       v_26
#
#                       description  size  std_sales_price  purchase_price  bio  \
# ...

# %%
def week_of_year(row):
    week_nr = row["day"].isocalendar()[2]
    return week_nr

transactions["day of week"] = transactions.apply(week_of_year, axis=1)

# %%
import plotly.express as px
dayofweek = transactions.groupby(["nday","day of week"]).count()["customer"]
dayofweek
# Out:
# nday   day of week
# 1.0    1              1147
# 2.0    4               844
# 3.0    4               793
# 4.0    7               616
# 5.0    2               783
#                       ...
# 360.0  3               738
# 361.0  4               668
# 362.0  5               654
# 363.0  6               909
# 364.0  7               961
# Name: customer, Length: 364, dtype: int64

# %%
days = [dayofweek.index[i][0] for i in range(len(dayofweek))]
weekdays = [dayofweek.index[i][1] for i in range(len(dayofweek))]
df_weekday = pd.DataFrame({"days":days, "day of week":weekdays, "transactions":dayofweek.values})
df_weekday
# Out:
#       days  day of week  transactions
# 0      1.0            1          1147
# 1      2.0            4           844
# 2      3.0            4           793
# 3      4.0            7           616
# 4      5.0            2           783
# ..     ...          ...           ...
# 359  360.0            3           738
# 360  361.0            4           668
# 361  362.0            5           654
# 362  363.0            6           909
# 363  364.0            7           961
#
# [364 rows x 3 columns]

# %%
fig = px.box(df_weekday, x="day of week", y="transactions", color="day of week", title="Distribution of transactions per day of week")
fig.show()

# %%
transactions_hourly = transactions.groupby(["nday","hour"]).agg({"customer":"nunique"})
days = [transactions_hourly.index[i][0] for i in range(len(transactions_hourly))]
hours = [transactions_hourly.index[i][1] for i in range(len(transactions_hourly))]
customer_values = [transactions_hourly.iloc[i][0] for i in range(len(transactions_hourly))]

df_transactions = pd.DataFrame({"days":days, "hours":hours, "customers":customer_values})
df_transactions
# Out:
#        days  hours  customers
# 0       1.0    9.0          3
# 1       1.0   10.0          5
# 2       1.0   11.0          6
# 3       1.0   12.0          2
# 4       1.0   13.0          8
# ...     ...    ...        ...
# 4315  364.0   16.0          4
# 4316  364.0   17.0          5
# 4317  364.0   18.0          5
# 4318  364.0   19.0          4
# 4319  364.0   20.0          3
#
# [4320 rows x 3 columns]

# %%
fig = px.box(df_transactions, x="hours", y="customers")
fig.show()

# %%
transactions_hourly = transactions.groupby(["nday","day of week"]).agg({"customer":"nunique"})
days = [transactions_hourly.index[i][0] for i in range(len(transactions_hourly))]
hours = [transactions_hourly.index[i][1] for i in range(len(transactions_hourly))]
customer_values = [transactions_hourly.iloc[i][0] for i in range(len(transactions_hourly))]

df_transactions = pd.DataFrame({"days":days, "day of week":hours, "customers":customer_values})
df_transactions
# Out:
#       days  day of week  customers
# 0      1.0            1         63
# 1      2.0            4         47
# 2      3.0            4         53
# 3      4.0            7         45
# 4      5.0            2         51
# ..     ...          ...        ...
# 359  360.0            3         47
# 360  361.0            4         44
# 361  362.0            5         39
# 362  363.0            6         46
# 363  364.0            7         47
#
# [364 rows x 3 columns]

# %%
fig = px.box(df_transactions, x="day of week", y="customers", title="Distribution of customers per day of week")
fig.show()

# %% [markdown]
# ## Line plots for customers

# %%
df_weekly = pd.DataFrame({"dayofweek":dayofweek.index, "nr transactions":dayofweek.values})
fig = px.line(df_weekly, x = "dayofweek", y="nr transactions", title="Number of transactions per week")
fig.update_yaxes(range=(4.5e4, 5.8e4))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-807d652f3364> in <module>
# ----> 1 df_weekly = pd.DataFrame({"dayofweek":dayofweek.index, "nr transactions":dayofweek.values})
#       2 fig = px.line(df_weekly, x = "dayofweek", y="nr transactions", title="Number of transactions per week")
#       3 fig.update_yaxes(range=(4.5e4, 5.8e4))
#       4 fig.show()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
# ...

# %%
nr_customers = transactions.groupby("hour").agg({"customer":"nunique"})
fig = px.line(nr_customers, x = nr_customers.index, y="customer", title="Amount of customers in each hour")
fig.update_yaxes(range=(1300, 2200))
fig.show()

# %%
nr_customer_pw = transactions.groupby("day of week").agg({"customer":"nunique"})
fig = px.line(nr_customer_pw, x = nr_customer_pw.index, y="customer", title="Number of customers per week")
fig.update_yaxes(range=(2500, 3200))
fig.show()
